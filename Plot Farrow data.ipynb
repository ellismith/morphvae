# %%
import os

import pandas as pd
import numpy as np
from scipy.io import savemat


## plotting ###

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### plot data

# %%
import warnings

warnings.filterwarnings('ignore')
import numpy as np

# %%
from utils.rw_utils import load_neurons
import os

neurons = load_neurons('./data/Farrow_data/neurons/soma_centered/', sort=False)

root, _, files = list(os.walk('./data/Farrow_data/neurons/soma_centered/'))[0]
sort_index = np.array(files).argsort()

neurons = np.array(neurons)[sort_index]

labels = pd.read_csv("./data/Farrow_data/meta_data_labeled_cells.csv")

# %%
path_angles = np.concatenate([list(n.get_path_angles().values()) for n in neurons])
branch_angles = np.concatenate([list(n.get_branch_angles().values()) for n in neurons])

# %%
np.percentile(branch_angles,95)
# Out:
# 107.12682354427379

# %%
np.random.seed(42)
n_samples = 1
onoffds_index = np.random.choice(np.where(labels['clusterA'] == 'clus4')[0], size=n_samples, replace=False)
soffa_index = np.random.choice(np.where(labels['clusterA'] == 'clus1')[0], size=n_samples, replace=False)
tona_index = np.random.choice(np.where(labels['clusterA'] == 'clus11')[0], size=n_samples, replace=False) 
fminion_index = np.random.choice(np.where(labels['clusterA'] == 'clus9')[0], size=n_samples, replace=False) 
type_indices = np.concatenate((soffa_index, onoffds_index, tona_index,fminion_index))

# %%
np.random.seed(17)
type_indices = []
for c in ['clus1', 'clus2','clus4', 'clus5', 'clus6', 'clus8', 'clus10', 'clus13']:
    c_index = np.random.choice(np.where(labels['clusterA'] == c)[0], size=1, replace=False)
    type_indices = np.concatenate((type_indices, c_index))
type_indices = type_indices.astype(int)

# %%
cluster_ids = [int(f[4:]) for f in np.unique(labels['clusterA'])[17:]]
cluster_ids.sort()
colors = dict(zip(['clus%i'%i for i in cluster_ids ],sns.color_palette('icefire', n_colors=15)))

# %%
fig, axes = plt.subplots(1,8, sharex=True, sharey=True, figsize=(12,4))

for k, ix_ in enumerate(type_indices):
    
    c = colors[labels.iloc[ix_]['clusterA']]
    print(c)
    neurons[ix_].draw_2D(ax=axes[k], dendrite_color=c, projection='xy')
    axes[k].axis('off')
    axes[k].set_aspect('equal')
    axes[k].scatter(0, 0, c='k', marker='s', zorder=10, s=8)
    
    inset_axis = axes[k].inset_axes([.6,.8,.4,.4])
    neurons[ix_].draw_2D(ax=inset_axis, dendrite_color=c, projection='xz')
    inset_axis.axis('off')
    inset_axis.set_aspect('equal')
    
    if k == 1:
        axes[1].plot([-2,-1], [-3,-3], c='k', linewidth=2)
#         inset_axis.plot([-2,-1], [-1.5,-1.5], c='k', linewidth=3)

plt.tight_layout()
fig.subplots_adjust(wspace=-.15)
plt.savefig('./pics/ICML/camera-ready/Fig2/Fig2_rgc.svg', format='svg')
# Out:
# (0.56349779, 0.78357215, 0.81834861)
# (0.37523981, 0.67057537, 0.80420832)
# (0.25423116, 0.40433127, 0.78155831)
# (0.28233561, 0.28527482, 0.58742866)
# (0.2156198, 0.20755389, 0.36125301)
# (0.12284806, 0.1179729, 0.11772022)
# (0.36178937, 0.1589124, 0.20807639)
# (0.85648867, 0.32358058, 0.20415327)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/ellismith/morphvae/Plot Farrow data.ipynb Cell 12' in <cell line: 23>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bspike/home/ellismith/morphvae/Plot%20Farrow%20data.ipynb#ch0000009vscode-remote?line=20'>21</a> plt.tight_layout()
#      <a href='vscode-notebook-cell://ssh-remote%2Bspike/home/ellismith/morphvae/Plot%20Farrow%20data.ipynb#ch0000009vscode-remote?line=21'>22</a> fig.subplots_adjust(wspace=-.15)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bspike/home/ellismith/morphvae/Plot%20Farrow%20data.ipynb#ch0000009vscode-remote?line=22'>23</a> plt.savefig('./pics/ICML/camera-ready/Fig2/Fig2_rgc.svg', format='svg')
#
# File /opt/mambaforge/lib/python3.9/site-packages/matplotlib/pyplot.py:966, in savefig(*args, **kwargs)
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/pyplot.py?line=962'>963</a> @_copy_docstring_and_deprecators(Figure.savefig)
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/pyplot.py?line=963'>964</a> def savefig(*args, **kwargs):
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/pyplot.py?line=964'>965</a>     fig = gcf()
# --> <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/pyplot.py?line=965'>966</a>     res = fig.savefig(*args, **kwargs)
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/pyplot.py?line=966'>967</a>     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/pyplot.py?line=967'>968</a>     return res
#
# File /opt/mambaforge/lib/python3.9/site-packages/matplotlib/figure.py:3005, in Figure.savefig(self, fname, transparent, **kwargs)
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/figure.py?line=3001'>3002</a>         patch.set_facecolor('none')
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/figure.py?line=3002'>3003</a>         patch.set_edgecolor('none')
# -> <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/figure.py?line=3004'>3005</a> self.canvas.print_figure(fname, **kwargs)
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/figure.py?line=3006'>3007</a> if transparent:
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/figure.py?line=3007'>3008</a>     for ax, cc in zip(self.axes, original_axes_colors):
#
# File /opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py:2255, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2250'>2251</a> try:
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2251'>2252</a>     # _get_renderer may change the figure dpi (as vector formats
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2252'>2253</a>     # force the figure dpi to 72), so we need to set it again here.
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2253'>2254</a>     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2254'>2255</a>         result = print_method(
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2255'>2256</a>             filename,
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2256'>2257</a>             facecolor=facecolor,
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2257'>2258</a>             edgecolor=edgecolor,
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2258'>2259</a>             orientation=orientation,
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2259'>2260</a>             bbox_inches_restore=_bbox_inches_restore,
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2260'>2261</a>             **kwargs)
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2261'>2262</a> finally:
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backend_bases.py?line=2262'>2263</a>     if bbox_inches and restore_bbox:
#
# File /opt/mambaforge/lib/python3.9/site-packages/matplotlib/backends/backend_svg.py:1321, in FigureCanvasSVG.print_svg(self, filename, *args, **kwargs)
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backends/backend_svg.py?line=1288'>1289</a> def print_svg(self, filename, *args, **kwargs):
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backends/backend_svg.py?line=1289'>1290</a>     """
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backends/backend_svg.py?line=1290'>1291</a>     Parameters
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backends/backend_svg.py?line=1291'>1292</a>     ----------
#    (...)
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backends/backend_svg.py?line=1318'>1319</a>         __ DC_
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backends/backend_svg.py?line=1319'>1320</a>     """
# -> <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backends/backend_svg.py?line=1320'>1321</a>     with cbook.open_file_cm(filename, "w", encoding="utf-8") as fh:
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backends/backend_svg.py?line=1322'>1323</a>         filename = getattr(fh, 'name', '')
#    <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/backends/backend_svg.py?line=1323'>1324</a>         if not isinstance(filename, str):
#
# File /opt/mambaforge/lib/python3.9/contextlib.py:117, in _GeneratorContextManager.__enter__(self)
#     <a href='file:///opt/mambaforge/lib/python3.9/contextlib.py?line=114'>115</a> del self.args, self.kwds, self.func
#     <a href='file:///opt/mambaforge/lib/python3.9/contextlib.py?line=115'>116</a> try:
# --> <a href='file:///opt/mambaforge/lib/python3.9/contextlib.py?line=116'>117</a>     return next(self.gen)
#     <a href='file:///opt/mambaforge/lib/python3.9/contextlib.py?line=117'>118</a> except StopIteration:
#     <a href='file:///opt/mambaforge/lib/python3.9/contextlib.py?line=118'>119</a>     raise RuntimeError("generator didn't yield") from None
#
# File /opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:477, in open_file_cm(path_or_file, mode, encoding)
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py?line=473'>474</a> @contextlib.contextmanager
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py?line=474'>475</a> def open_file_cm(path_or_file, mode="r", encoding=None):
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py?line=475'>476</a>     r"""Pass through file objects and context-manage path-likes."""
# --> <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py?line=476'>477</a>     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py?line=477'>478</a>     if opened:
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py?line=478'>479</a>         with fh:
#
# File /opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:462, in to_filehandle(fname, flag, return_opened, encoding)
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py?line=459'>460</a>         fh = bz2.BZ2File(fname, flag)
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py?line=460'>461</a>     else:
# --> <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py?line=461'>462</a>         fh = open(fname, flag, encoding=encoding)
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py?line=462'>463</a>     opened = True
#     <a href='file:///opt/mambaforge/lib/python3.9/site-packages/matplotlib/cbook/__init__.py?line=463'>464</a> elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './pics/ICML/camera-ready/Fig2/Fig2_rgc.svg'
